# %% [markdown]
# **Summary [Salvador Robles]**:
#
# In this process, we have performed the **Data Wrangling step** of the Data Science method.In big lines, we have
# * (i) defined the *foundational questions* that we will be answering in the project,
# * (ii) analyzed the *structure, size and characteristics* of the raw data, and
# * (iii) modified the raw data to *better understand and organize the dataset*.
#
# To do this, we have
# * a) explored the data,
#   * our resort - Montana Resort, all it's columns are populated.
#   * nº of missing values per column - We have calculated the nº and percentage of missing rows per column. Note: Pending to check how to drop/fill/leave the values.
#   * categorical features - We have better understood the relationship between Region and state in the dataset. Region is smaller than state. Also, there are no duplicated values in the dataset.
#   * numeric features - We have checked the distribution of values of numeric variables and dropped some outliers.
# * b) derived some statistics from it,
#   * We have calculated state-wise statistics of market segment. In particular, for variables 'TerrainParks', 'SkiableTerrain_ac', 'daysOpenLastYear' and 'NightSkiing_ac'.
# * c) dropped certain rows (based on our initial findings), and
#   * Droped rows with no price data at all, in total 14% of the resorts had no price data.
# * d) defined the target feature for our analysis.
#
# As a result of the work performed on the raw data, we have generated a **cleaned dataset**.
#
# In the upcoming lines, we summarize the steps that we have followed to reach the cleaned dataset, some issues that we have encountered, and how the size of the dataset have changed through the process.
#
# ## 2.3 Imports
# * We imported the necessary libraries for this step:
#     * **pandas:** *to operate with data frames*
#     * **matplotlib.pyplot:** *to plot data*
#     * **seaborn:** *to visualize data*
#     * **os:** *to interact with the operating system*
# ***
# ## 2.4 Objectives
# * The following questions define the fundamental topics that we are seeking to understand from the data:
#
# * **Do you think you may have the data you need to tackle the desired question?** After our analysis, it is reasonable to state, (without considering the missing values yet), that we have sufficient data to build a model that explains the price of chairlift tickets.
#
#     * **Have you identified the required target value?** The target value is **price of week and weekend chairlifts**.
#
#     * **Do you have potentially useful features?** We have several potentially useful features, such as **geographical data** (Region and state of each Resort), **structural data** (nº of acres of skiable area, average snowfall,...), and **operative data** (nº of chairlift chairs, acres of snowmaking,...). Having different types of data sets good foundations for further analyses and interrelations.
#
# * **Do you have any fundamental issues with the data?** The main issue we have encountered is that we have many columns with a high percentage of missing values. In particular, there are 2 columns with close to 50% of missing values, and a second group of columns with missing values of around 15%. About half of the columns have no missing values.
#
# ***
# ## 2.5 Load the Data
# **Loaded the data:** from local repository, csv file
# * .info() - shows columns names, non-null value counts and datatypes of each column.
#   * **result:** - raw data size = 330 rows * 27 columns. // non null = there are missing values // dtypes = 3 object - 11 integer // 13 float
# * .head() - check how the raw data looks like.
#   * **result** - columns look good, we can already see some NaN on the observations.
# ***
# ## 2.6 Explore the data
# In this step, we have analyzed topics such as:
# * (i) our resort data - does our client's resort have all the information populated?
# * (ii) nº of missing values by column - initial analysis of columns with missing values
# * (iii) categorical features - understand relationship between state/Region. Leading to calculate the avg weekend and weekday price per state.
# * (iv) numeric features - analysis of distribution leading to cleaning of outliers.
#
# ***
# ### 2.6.1 Find Resort of Interest
# We have filtered our resort and transpose the data to check it's values.
# * **Why?:** To check missing values, other issues with data, anticipate problems.
# * **result:** There are no missing values, we can proceed with the other observations of dataset.
# ***
# ### 2.6.2 Nº of missing values by column
# We have performed an analysis of the nº of observations missing on each column as well as their %. **why?** to have an preliminar idea of how many missing datapoints we have for each feature. **result** there are 13 columns with missing values:
#
# Percentages of missing values per column:
# fastEight 50.30%
# NightSkiing_ac 43.33%
# AdultWeekday 16.36%
# AdultWeekend 15.45%
# daysOpenLastYear 15.45%
# TerrainParks 15.45%
# projectedDaysOpen 14.24%
# Snow Making_ac 13.93%
# averageSnowfall 4.24%
# LongestRun_mi 1.51%
# Runs 1.21%
# SkiableTerrain_ac 0.90%
# yearsOpen 0.30%
#
# The method used, involving isnull() does not compute null values derived from outliers in the data. Therefore, there could be more missing values than the percentages included here. To find those outliers, a DataDictionary and/or focused searching must be considered.
# ***
# ### 2.6.3 Categorical features
# We have analyzed the categorical features of the dataset ('Name', 'Region' and 'state') to undertand the relationships between them, as apparently, 'Region' and 'State' are definitions of geographical territory. Later on in the analysis, it will be useful to understand how are they related with eachother (e.g.is state within a Region, or viceversa).
#
# **Are there duplicated values in the dataset?**
#
# Filtering of the dataset by dtypes object shows that Region and State are the same on head and tail. We wanted to contrast this hypothesis for all dataset. **how**To do so, we proceeded to **count on filtered unique values on Name**. It showed that Crystal Mountain Name appears 2 times. To further contrast the hypothesis, we **concatenate Name and Region**, it didn't give duplicate results. We did the same with **Name and state**, it didn't give duplicates. **result** there are no duplicate values in the dataset.
#
# We filtered on dataset by Name 'Crystal Mountain' to check the observations and confirm that the Region and state is different. **result** We confirm that they have different Region and state.
#
# **What's the relationship between Region and State?**
#
# We want to know if state is within a Region, if a Region is within a state, how many times the Region and the state are equal or different. If we can understand their relationship, this will provide guidance on future criteria regarding how to approach the problem.
#
#
# ***
# ### 2.6.4 Numeric features
# ***
# ## 2.7 Derive State-wide statistics
# ***
# ## 2.8 Drop rows with no price data
# ***
# ## 2.9 Review distributions
# ***
# ## 2.10 Population data
# ***
# ## 2.11 Target feature
# ***
# ### 2.11.1 Number Of Missing Values By Row - Resort
# ***
# ## 2.12 Save data
# ***
